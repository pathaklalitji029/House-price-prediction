# %%
#Here we import some libraries that is neccessary for dataset to predict the price of house by regression model
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
#Read the csv file 
df=pd.read_csv('home_prices.csv')

# %%
df.head()
# Out:
#    area   price
# 0  1360  154206
# 1  4272  677854
# 2  3592  576697
# 3   966  118319
# 4  4926  739536

# %%
#Here we plot the graph to visualise  and compare price,area of house  
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.area,df.price,color='blue',marker='+')
plt.show()

# %%
new_df = df.drop('price',axis='columns')
new_df
# Out:
#     area
# 0   1360
# 1   4272
# 2   3592
# 3    966
# 4   4926
# ..   ...
# 95  1528
# 96  1002
# 97  4993
# 98  1370
# 99  4988
#
# [100 rows x 1 columns]

# %%
prices=df.price
price
# Out:
# 0     154206
# 1     677854
# 2     576697
# 3     118319
# 4     739536
#        ...
# 95    244933
# 96    189345
# 97    733648
# 98    236123
# 99    720871
# Name: price, Length: 100, dtype: int64

# %%
#train regression model
reg= LinearRegression()
reg.fit(new_df,prices)
# Out:
# LinearRegression()

# %%
Predicted_price=reg.predict([[3300]])
Predicted_price
# Out:
# C:\Users\Lalit Pathak\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([497869.68175032])

# %%
#Now we checl that the predcit value is correct or not by check the y=mx+c of linear regression 
reg.coef_
# Out:
# array([148.27816676])

# %%
reg.intercept_
# Out:
# np.float64(8551.731434376794)

# %%
#y=mx+c, here m=148.27816676 x=3300 c=8551.731434376794

148.27816676*3300+8551.731434376794
# Out:
# 497869.6817423768

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
x=df[['area']]
y=df[['price']]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)

# %%
print('cofficient (slope):',reg.coef_[0])
print('Intercept:',reg.intercept_)
print('MSE:',mean_squared_error(y_test,y_pred))
print('R2^score:',r2_score(y_test,y_pred))
# Out:
# cofficient (slope): [146.55140903]
# Intercept: [13493.97543013]
# MSE: 707985667.7953734
# R2^score: 0.9872029784427683
